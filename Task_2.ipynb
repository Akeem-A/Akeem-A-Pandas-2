# %% [markdown]
# <a href="https://colab.research.google.com/github/Akeem-A/Akeem-A/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Linking Google Drive to Collab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importing the "Data Analyst Sample" from MyDrive
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/Data_Analyst_Sample.csv', index_col = 0)
print(df)
# Out:
#                                                     Campaign ID  \
# Campaign Name
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# ...                                                         ...
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDis_Pro...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticVideo_P...     24922332
#
#                                                                                             Placement  \
# Campaign Name
# ...

# %%
#Using Sample function to explore the data
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/Data_Analyst_Sample.csv', index_col = 0)
df.sample()
# Out:
#                                                     Campaign ID  \
# Campaign Name
# CY21_Q1_LOC_IT_Smart_Fortwo_ProgrammaticVideo_P...     25420695
#
#                                                                  Placement  \
# Campaign Name
# CY21_Q1_LOC_IT_Smart_Fortwo_ProgrammaticVideo_P...  ITALIA_SMART_DV360_15"
#
#                                                           Date  Impressions  \
# Campaign Name
# CY21_Q1_LOC_IT_Smart_Fortwo_ProgrammaticVideo_P...  03/03/2021       3336.0
#
#                                                     Clicks  Cost  \
# Campaign Name
# CY21_Q1_LOC_IT_Smart_Fortwo_ProgrammaticVideo_P...       1  5.17
#
#                                                     Video Completions  \
# Campaign Name
# CY21_Q1_LOC_IT_Smart_Fortwo_ProgrammaticVideo_P...               1769
#
#                                                     Find A Dealer Conversion  \
# Campaign Name
# ...

# %%
#Using Tail to explore the data
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/Data_Analyst_Sample.csv', index_col = 0)
print(df.tail(4))
# Out:
#                                                     Campaign ID  \
# Campaign Name
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDis_Pro...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticVideo_P...     24922332
#
#                                                                                      Placement  \
# Campaign Name
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...  ES_Smart_Fortwo_TTD_TbMb_Contextual_728x90
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...  ES_Smart_Fortwo_TTD_TbMb_Contextual_728x90
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDis_Pro...  ES_Smart_Fortwo_TTD_TbMb_Contextual_728x90
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticVideo_P...     ES_Smart_Fortwo_TTD_DkTbMb_Interest_30"
#
#                                                           Date  Impressions  \
# Campaign Name
# ...

# %%
#Using describe function to explore the data
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/Data_Analyst_Sample.csv', index_col = 0)
df.describe()
# Out:
#         Campaign ID   Impressions        Clicks          Cost  \
# count  5.248100e+04  5.245100e+04  52481.000000  52458.000000
# mean   2.537639e+07  4.841354e+03     29.774356     28.538750
# std    4.054270e+04  2.562214e+04    176.324974    167.347141
# min    2.492233e+07  0.000000e+00      0.000000      0.000000
# 25%    2.533641e+07  6.100000e+01      0.000000      0.270000
# 50%    2.536894e+07  4.120000e+02      1.000000      1.970000
# 75%    2.541376e+07  2.258000e+03      4.000000     11.530000
# max    2.553608e+07  2.537059e+06   7662.000000  11826.480000
#
#        Video Completions  Find A Dealer Conversion  Online Brochure Download
# count       52481.000000              52481.000000              52481.000000
# mean          995.629104                  3.051790                  1.231589
# std          5552.026890                 21.285292                  8.802559
# min             0.000000                  0.000000                  0.000000
# ...

# %%
#Finding out the Number of Rows & Columns in the Data. 52,481 Rows & 9 Columns.
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/Data_Analyst_Sample.csv', index_col = 0)
df.shape
# Out:
# (52481, 9)

# %%
#Finding out which columns have missing values "Date" & "Cost" have missing values with a total of 83 rows containing missing values.
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/Data_Analyst_Sample.csv', index_col = 0)

ndf = df[df.isnull().any(axis=1)]

print(ndf)
# Out:
#                                                     Campaign ID  \
# Campaign Name
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Cla_ProgrammaticDispl...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_MercedesS-Class_ProgrammaticDisp...     25413759
# ...                                                         ...
# CY21_Q1_LOC_ES_C-Class_Mercedes_ProgrammaticVid...     25336315
# CY21_Q1_LOC_ES_C-Class_Mercedes_ProgrammaticVid...     25336315
# CY21_Q1_LOC_ES_C-Class_Mercedes_ProgrammaticVid...     25336315
# CY21_Q1_LOC_ES_C-Class_Mercedes_ProgrammaticVid...     25336315
# CY21_Q1_LOC_ES_C-Class_Mercedes_ProgrammaticVid...     25336315
#
#                                                                                             Placement  \
# Campaign Name
# ...

# %%
#Using "dropna" to remove missing values from the data
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/Data_Analyst_Sample.csv', index_col = 0)

newdf = df.dropna()

print(newdf)
# Out:
#                                                     Campaign ID  \
# Campaign Name
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# ...                                                         ...
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDis_Pro...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticVideo_P...     24922332
#
#                                                                                             Placement  \
# Campaign Name
# ...

# %%
#Replacing the Missing values with "0"
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wk10_pandas_learner/Task_resources/Data_Analyst_Sample.csv', index_col = 0)

df.fillna(0, inplace = True)

print(df.to_string)
# Out:
# <bound method DataFrame.to_string of                                                     Campaign ID  \
# Campaign Name
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDis...     25347887
# ...                                                         ...
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDis_Pro...     25362071
# CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticVideo_P...     24922332
#
#                                                                                             Placement  \
# Campaign Name
# ...
